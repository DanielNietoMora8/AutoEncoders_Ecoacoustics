# %% [markdown]
# #librerias y ubicacion directorio

# %%
from google.colab import drive #Acceso Drive
import os #Acceder a directorios
import pandas as pd #manejo de dataframes
import folium #mostrar mapa con geocolocacion 
import numpy as np #Numerical Python
import librosa
import IPython.display as ipd

# %%
#Damos acceso a colab a nuestro Drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %%
#Nos ubicamos en la direccion de interes
ruta_py="/content/drive/MyDrive/Semillero_IA/acoustic_exploration"
os.chdir(ruta_py) #Ubicarnos en el directorio
print("Ubicados en :",ruta_py)
# !ls
# Out:
# Ubicados en : /content/drive/MyDrive/Semillero_IA/acoustic_exploration
#  AE_Framework			        df_audios.csv
#  Base_Etiquetas_LLuvia_26Abr.csv        df_grabadoras.csv
#  BioAcustica.ipynb		        mapa_grabadoras.html
#  Clusterizando			        README.md
# 'Copia de Recorrido_individual.ipynb'   Recorrido_individual.ipynb
#  df_audios_cluster.csv		        Recorrido.ipynb

# %%
df = pd.read_csv("df_audios.csv")
df3 = pd.read_csv("Base_Etiquetas_LLuvia_26Abr.csv")

# %%
df
# Out:
#                  Recording Recorder        Date      Time  \
# 0      G03_20180511_120000      G03  2018/05/11  12:00:00
# 1      G03_20180511_121600      G03  2018/05/11  12:16:00
# 2      G03_20180511_123200      G03  2018/05/11  12:32:00
# 3      G03_20180511_124800      G03  2018/05/11  12:48:00
# 4      G03_20180511_130400      G03  2018/05/11  13:04:00
# ...                    ...      ...         ...       ...
# 20063  G58_20180704_070000      G58  2018/07/04  07:00:00
# 20064  G58_20180704_064500      G58  2018/07/04  06:45:00
# 20065  G58_20180704_071500      G58  2018/07/04  07:15:00
# 20066  G58_20180704_073000      G58  2018/07/04  07:30:00
# 20067  G58_20180704_074500      G58  2018/07/04  07:45:00
#
#                                                     Path   Municipio  \
# 0      /content/drive/MyDrive/Jaguas_2018/G03_m/G03_2...  Alejandria
# 1      /content/drive/MyDrive/Jaguas_2018/G03_m/G03_2...  Alejandria
# 2      /content/drive/MyDrive/Jaguas_2018/G03_m/G03_2...  Alejandria
# 3      /content/drive/MyDrive/Jaguas_2018/G03_m/G03_2...  Alejandria
# 4      /content/drive/MyDrive/Jaguas_2018/G03_m/G03_2...  Alejandria
# ...                                                  ...         ...
# 20063  /content/drive/MyDrive/Jaguas_2018/G58_m/G58_2...  San Rafael
# 20064  /content/drive/MyDrive/Jaguas_2018/G58_m/G58_2...  San Rafael
# 20065  /content/drive/MyDrive/Jaguas_2018/G58_m/G58_2...  San Rafael
# 20066  /content/drive/MyDrive/Jaguas_2018/G58_m/G58_2...  San Rafael
# 20067  /content/drive/MyDrive/Jaguas_2018/G58_m/G58_2...  San Rafael
#
#                             Vereda  Latitud  Longitud  Elevacion Habitat
# 0                      El Respaldo   6.4137  -75.0366       1322  Forest
# 1                      El Respaldo   6.4137  -75.0366       1322  Forest
# 2                      El Respaldo   6.4137  -75.0366       1322  Forest
# 3                      El Respaldo   6.4137  -75.0366       1322  Forest
# 4                      El Respaldo   6.4137  -75.0366       1322  Forest
# ...                            ...      ...       ...        ...     ...
# 20063  Area proteccion embalse EPM   6.3471  -74.9696       1072  Forest
# 20064  Area proteccion embalse EPM   6.3471  -74.9696       1072  Forest
# 20065  Area proteccion embalse EPM   6.3471  -74.9696       1072  Forest
# 20066  Area proteccion embalse EPM   6.3471  -74.9696       1072  Forest
# 20067  Area proteccion embalse EPM   6.3471  -74.9696       1072  Forest
#
# [20068 rows x 11 columns]

# %%
df["Path"][0]
# Out:
# 'G03_20180511_120000.wav'

# %%
df["Path"] = df["Path"].apply(lambda x: os.path.basename(x))

# %%
df = df.rename(columns={"Path": "Filename"})

# %%
df
# Out:
#                  Recording Recorder        Date      Time  \
# 0      G03_20180511_120000      G03  2018/05/11  12:00:00
# 1      G03_20180511_121600      G03  2018/05/11  12:16:00
# 2      G03_20180511_123200      G03  2018/05/11  12:32:00
# 3      G03_20180511_124800      G03  2018/05/11  12:48:00
# 4      G03_20180511_130400      G03  2018/05/11  13:04:00
# ...                    ...      ...         ...       ...
# 20063  G58_20180704_070000      G58  2018/07/04  07:00:00
# 20064  G58_20180704_064500      G58  2018/07/04  06:45:00
# 20065  G58_20180704_071500      G58  2018/07/04  07:15:00
# 20066  G58_20180704_073000      G58  2018/07/04  07:30:00
# 20067  G58_20180704_074500      G58  2018/07/04  07:45:00
#
#                       Filename   Municipio                       Vereda  \
# 0      G03_20180511_120000.wav  Alejandria                  El Respaldo
# 1      G03_20180511_121600.wav  Alejandria                  El Respaldo
# 2      G03_20180511_123200.wav  Alejandria                  El Respaldo
# 3      G03_20180511_124800.wav  Alejandria                  El Respaldo
# 4      G03_20180511_130400.wav  Alejandria                  El Respaldo
# ...                        ...         ...                          ...
# 20063  G58_20180704_070000.wav  San Rafael  Area proteccion embalse EPM
# 20064  G58_20180704_064500.wav  San Rafael  Area proteccion embalse EPM
# 20065  G58_20180704_071500.wav  San Rafael  Area proteccion embalse EPM
# 20066  G58_20180704_073000.wav  San Rafael  Area proteccion embalse EPM
# 20067  G58_20180704_074500.wav  San Rafael  Area proteccion embalse EPM
#
#        Latitud  Longitud  Elevacion Habitat
# 0       6.4137  -75.0366       1322  Forest
# 1       6.4137  -75.0366       1322  Forest
# 2       6.4137  -75.0366       1322  Forest
# 3       6.4137  -75.0366       1322  Forest
# 4       6.4137  -75.0366       1322  Forest
# ...        ...       ...        ...     ...
# 20063   6.3471  -74.9696       1072  Forest
# 20064   6.3471  -74.9696       1072  Forest
# 20065   6.3471  -74.9696       1072  Forest
# 20066   6.3471  -74.9696       1072  Forest
# 20067   6.3471  -74.9696       1072  Forest
#
# [20068 rows x 11 columns]

# %%
df3=df3[["Filename","Rain_occurrence","Rain_Intesity","Intensity_Category"]]

# %%
df3
# Out:
#                       Filename  Rain_occurrence  Rain_Intesity  \
# 0      G03_20180511_120000.wav                0              0
# 1      G03_20180511_121600.wav                0              0
# 2      G03_20180511_123200.wav                0              0
# 3      G03_20180511_124800.wav                0              0
# 4      G03_20180511_130400.wav                0              0
# ...                        ...              ...            ...
# 20063  G58_20180704_083200.wav                0              0
# 20064  G58_20180704_084800.wav                0              0
# 20065  G58_20180704_090400.wav                0              0
# 20066  G58_20180704_092000.wav                0              0
# 20067  G58_20180704_093600.wav                0              0
#
#       Intensity_Category
# 0                No_rain
# 1                No_rain
# 2                No_rain
# 3                No_rain
# 4                No_rain
# ...                  ...
# 20063            No_rain
# 20064            No_rain
# 20065            No_rain
# 20066            No_rain
# 20067            No_rain
#
# [20068 rows x 4 columns]

# %%
merged_df = pd.merge(df, df3, on="Filename")

# %%
merged_df.to_csv("Audios_Jaguas.csv", index=True)

# %%
merged_df["Recorder"].value_counts().sort_index().index
# Out:
# Index(['G03', 'G04', 'G06', 'G07', 'G08', 'G09', 'G13', 'G15', 'G17', 'G19',
#        'G23', 'G24', 'G25', 'G27', 'G28', 'G29', 'G34', 'G35', 'G36', 'G37',
#        'G40', 'G41', 'G46', 'G47', 'G49', 'G50', 'G51', 'G52', 'G54', 'G57',
#        'G58'],
#       dtype='object')

# %%
filtro_G03 = df["Recorder"] == "G03"
G03 = df[filtro_G03].copy()
G03.to_csv("G03.csv", index=True)

# %%
merged_df
# Out:
#                  Recording Recorder        Date      Time  \
# 0      G03_20180511_120000      G03  2018/05/11  12:00:00
# 1      G03_20180511_121600      G03  2018/05/11  12:16:00
# 2      G03_20180511_123200      G03  2018/05/11  12:32:00
# 3      G03_20180511_124800      G03  2018/05/11  12:48:00
# 4      G03_20180511_130400      G03  2018/05/11  13:04:00
# ...                    ...      ...         ...       ...
# 20063  G58_20180704_070000      G58  2018/07/04  07:00:00
# 20064  G58_20180704_064500      G58  2018/07/04  06:45:00
# 20065  G58_20180704_071500      G58  2018/07/04  07:15:00
# 20066  G58_20180704_073000      G58  2018/07/04  07:30:00
# 20067  G58_20180704_074500      G58  2018/07/04  07:45:00
#
#                       Filename   Municipio                       Vereda  \
# 0      G03_20180511_120000.wav  Alejandria                  El Respaldo
# 1      G03_20180511_121600.wav  Alejandria                  El Respaldo
# 2      G03_20180511_123200.wav  Alejandria                  El Respaldo
# 3      G03_20180511_124800.wav  Alejandria                  El Respaldo
# 4      G03_20180511_130400.wav  Alejandria                  El Respaldo
# ...                        ...         ...                          ...
# 20063  G58_20180704_070000.wav  San Rafael  Area proteccion embalse EPM
# 20064  G58_20180704_064500.wav  San Rafael  Area proteccion embalse EPM
# 20065  G58_20180704_071500.wav  San Rafael  Area proteccion embalse EPM
# 20066  G58_20180704_073000.wav  San Rafael  Area proteccion embalse EPM
# 20067  G58_20180704_074500.wav  San Rafael  Area proteccion embalse EPM
#
#        Latitud  Longitud  Elevacion Habitat  Rain_occurrence  Rain_Intesity  \
# 0       6.4137  -75.0366       1322  Forest                0              0
# 1       6.4137  -75.0366       1322  Forest                0              0
# 2       6.4137  -75.0366       1322  Forest                0              0
# 3       6.4137  -75.0366       1322  Forest                0              0
# 4       6.4137  -75.0366       1322  Forest                0              0
# ...        ...       ...        ...     ...              ...            ...
# 20063   6.3471  -74.9696       1072  Forest                0              0
# 20064   6.3471  -74.9696       1072  Forest                0              0
# 20065   6.3471  -74.9696       1072  Forest                0              0
# 20066   6.3471  -74.9696       1072  Forest                0              0
# 20067   6.3471  -74.9696       1072  Forest                0              0
#
#       Intensity_Category
# 0                No_rain
# 1                No_rain
# 2                No_rain
# 3                No_rain
# 4                No_rain
# ...                  ...
# 20063            No_rain
# 20064            No_rain
# 20065            No_rain
# 20066            No_rain
# 20067            No_rain
#
# [20068 rows x 14 columns]

# %%
G03
# Out:
#                Recording Recorder        Date      Time  \
# 0    G03_20180511_120000      G03  2018/05/11  12:00:00
# 1    G03_20180511_121600      G03  2018/05/11  12:16:00
# 2    G03_20180511_123200      G03  2018/05/11  12:32:00
# 3    G03_20180511_124800      G03  2018/05/11  12:48:00
# 4    G03_20180511_130400      G03  2018/05/11  13:04:00
# ..                   ...      ...         ...       ...
# 560  G03_20180517_064500      G03  2018/05/17  06:45:00
# 561  G03_20180517_070000      G03  2018/05/17  07:00:00
# 562  G03_20180517_071500      G03  2018/05/17  07:15:00
# 563  G03_20180517_073000      G03  2018/05/17  07:30:00
# 564  G03_20180517_074500      G03  2018/05/17  07:45:00
#
#                     Filename   Municipio       Vereda  Latitud  Longitud  \
# 0    G03_20180511_120000.wav  Alejandria  El Respaldo   6.4137  -75.0366
# 1    G03_20180511_121600.wav  Alejandria  El Respaldo   6.4137  -75.0366
# 2    G03_20180511_123200.wav  Alejandria  El Respaldo   6.4137  -75.0366
# 3    G03_20180511_124800.wav  Alejandria  El Respaldo   6.4137  -75.0366
# 4    G03_20180511_130400.wav  Alejandria  El Respaldo   6.4137  -75.0366
# ..                       ...         ...          ...      ...       ...
# 560  G03_20180517_064500.wav  Alejandria  El Respaldo   6.4137  -75.0366
# 561  G03_20180517_070000.wav  Alejandria  El Respaldo   6.4137  -75.0366
# 562  G03_20180517_071500.wav  Alejandria  El Respaldo   6.4137  -75.0366
# 563  G03_20180517_073000.wav  Alejandria  El Respaldo   6.4137  -75.0366
# 564  G03_20180517_074500.wav  Alejandria  El Respaldo   6.4137  -75.0366
#
#      Elevacion Habitat
# 0         1322  Forest
# 1         1322  Forest
# 2         1322  Forest
# 3         1322  Forest
# 4         1322  Forest
# ..         ...     ...
# 560       1322  Forest
# 561       1322  Forest
# 562       1322  Forest
# 563       1322  Forest
# 564       1322  Forest
#
# [565 rows x 11 columns]

# %%
valores_recorder = ['G03', 'G04', 'G06', 'G07', 'G08', 'G09', 'G13', 'G15', 'G17', 'G19', 'G23', 'G24', 'G25', 'G27', 'G28', 'G29', 'G34', 'G35', 'G36', 'G37', 'G40', 'G41', 'G46', 'G47', 'G49', 'G50', 'G51', 'G52', 'G54', 'G57', 'G58']

for valor in valores_recorder:
    filtro = merged_df["Recorder"] == valor
    resultados = merged_df[filtro].copy()
    resultados.to_csv(f"{valor}.csv", index=True)

# %%
len(valores_recorder)
# Out:
# 31

# %%
import torch

if torch.cuda.is_available():
    device = torch.cuda.get_device_name(0)
    print("GPU utilizada:", device)
else:
    print("No se encontró una GPU disponible.")
# Out:
# GPU utilizada: Tesla T4

# %% [markdown]
# #Creacion Data Frame df_audios

# %%
# Crear un dataframe vacío para guardar la información de los archivos
df_audios = pd.DataFrame(columns=['Recording','Recorder', 'Date', 'Time', 'Path'])

# Recorrer las carpetas y archivos dentro de la ruta principal
for raiz, carpetas, archivos in os.walk(ruta_audios):
    carpetas.sort()
    # Recorrer los archivos de cada carpeta
    for archivo in archivos:
        # Obtener la ruta completa del archivo
        ruta_archivo = os.path.join(raiz, archivo)
        ruta_archivo = ruta_archivo.replace(ruta_audios, '')
        # Obtener el nombre del archivo sin la extensión
        nombre_archivo, extension = os.path.splitext(archivo)
        
        
        # Separar el nombre del archivo en partes utilizando el caracter "_"
        partes_nombre = nombre_archivo.split("_")
        
        # Obtener los valores deseados de cada parte del nombre del archivo
        recorder = partes_nombre[0]
        fecha = partes_nombre[1]
        hora = partes_nombre[2]
        nombre_archivo = archivo
        # Crear un diccionario con los valores del archivo actual
        datos_archivo = {
            'Recording': nombre_archivo,
            'Recorder': recorder,
            'Date': fecha,
            'Time': hora,
            'Path': ruta_archivo
        }
        
        # Agregar el diccionario al dataframe
        df_audios = df_audios.append(datos_archivo, ignore_index=True)


# Convertir la columna 'Date' al formato 'yyyy/mm/dd'
df_audios['Date'] = df_audios['Date'].apply(lambda x: pd.to_datetime(x, format='%Y%m%d').strftime('%Y/%m/%d'))

# Convertir la columna 'Time' al formato 'hh:mm:ss'
df_audios['Time'] = df_audios['Time'].apply(lambda x: pd.to_datetime(x, format='%H%M%S').strftime('%H:%M:%S'))

#Cargamos informacion adicional de las grabadoras
df_grabadoras = pd.read_csv(ruta_py+'/df_grabadoras.csv')
df_lluvia = pd.read_csv(ruta_py+'/Base_Etiquetas_LLuvia_26Abr.csv')
df_lluvia = df_lluvia.rename(columns={'Filename': 'Recording'})
df_lluvia = df_lluvia.drop(columns=['Site'])

#hacemos un Marge con el dataframe anteriormente creado, a base de recorrer los archivos
df_audios = pd.merge(df_audios, df_grabadoras, on="Recorder")
df_audios = pd.merge(df_audios, df_lluvia, on="Recording")
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)
# <ipython-input-6-5fcc0f067436>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_audios = df_audios.append(datos_archivo, ignore_index=True)

# %%
df_audios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20068 entries, 0 to 20067
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Recording           20068 non-null  object
#  1   Recorder            20068 non-null  object
#  2   Date                20068 non-null  object
#  3   Time                20068 non-null  object
#  4   Path                20068 non-null  object
#  5   Municipio           20068 non-null  object
#  6   Vereda              20068 non-null  object
#  7   Latitud             20068 non-null  float64
#  8   Longitud            20068 non-null  float64
#  9   Elevacion           20068 non-null  int64
#  10  Habitat             20068 non-null  object
#  11  Total_grabaciones   20068 non-null  int64
#  12  Rain_occurrence     20068 non-null  int64
#  13  Rain_Intesity       20068 non-null  int64
#  14  Intensity_Category  20068 non-null  object
# dtypes: float64(2), int64(4), object(9)
# memory usage: 2.4+ MB

# %%
df_audios.head()
# Out:
#                  Recording Recorder        Date      Time  \
# 0  G03_20180511_120000.wav      G03  2018/05/11  12:00:00
# 1  G03_20180511_121600.wav      G03  2018/05/11  12:16:00
# 2  G03_20180511_123200.wav      G03  2018/05/11  12:32:00
# 3  G03_20180511_124800.wav      G03  2018/05/11  12:48:00
# 4  G03_20180511_130400.wav      G03  2018/05/11  13:04:00
#
#                              Path   Municipio       Vereda  Latitud  Longitud  \
# 0  /G03_m/G03_20180511_120000.wav  Alejandria  El Respaldo   6.4137  -75.0366
# 1  /G03_m/G03_20180511_121600.wav  Alejandria  El Respaldo   6.4137  -75.0366
# 2  /G03_m/G03_20180511_123200.wav  Alejandria  El Respaldo   6.4137  -75.0366
# 3  /G03_m/G03_20180511_124800.wav  Alejandria  El Respaldo   6.4137  -75.0366
# 4  /G03_m/G03_20180511_130400.wav  Alejandria  El Respaldo   6.4137  -75.0366
#
#    Elevacion Habitat  Total_grabaciones  Rain_occurrence  Rain_Intesity  \
# 0       1322  Forest                565                0              0
# 1       1322  Forest                565                0              0
# 2       1322  Forest                565                0              0
# 3       1322  Forest                565                0              0
# 4       1322  Forest                565                0              0
#
#   Intensity_Category
# 0            No_rain
# 1            No_rain
# 2            No_rain
# 3            No_rain
# 4            No_rain

# %% [markdown]
# #Busqueda de Audios

# %%
print(df_audios['Intensity_Category'].value_counts())
print(df_audios['Rain_occurrence'].value_counts())
print(df_audios['Rain_Intesity'].value_counts())
# Out:
# No_rain     16964
# Light        2062
# Moderate      754
# Heavy         288
# Name: Intensity_Category, dtype: int64
# 0    16964
# 1     3104
# Name: Rain_occurrence, dtype: int64
# 0    16964
# 1     2062
# 2      754
# 3      288
# Name: Rain_Intesity, dtype: int64

# %%
for i, (index, row) in enumerate(df_audios.loc[(df_audios["Rain_Intesity"] == 1)].iterrows()):
    if i == 2: # salir después de 2 iteraciones
        break
    audio_path = ruta_audios + row["Path"]
    print(f"Iteración {i+1}: Abriendo archivo de audio en {audio_path}")
    print(row)
    audio, sr = librosa.load(audio_path)
    ipd.display(ipd.Audio(audio, rate=sr))
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Iterar sobre todos los elementos que cumplen las condiciones de "Rain_Intesity" igual a 1 o 2 y "Habitat" igual a "Forest"
for i, (index, row) in enumerate(df_audios.loc[(df_audios["Rain_Intesity"].isin([1, 2])) & (df_audios["Habitat"] == "Forest")].iterrows()):
    if i == 2: # salir después de 2 iteraciones
      break
    audio_path = ruta_audios + row["Path"]
    print(f"Iteración {i+1}: Abriendo archivo de audio en {audio_path}")
    print(row)
    audio, sr = librosa.load(audio_path)
    ipd.display(ipd.Audio(audio, rate=sr))
# Out:
# Output hidden; open in https://colab.research.google.com to view.
